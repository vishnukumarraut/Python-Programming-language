# %% [markdown]
# <a href="https://colab.research.google.com/github/vishnukumarraut/Python-Programming-language/blob/main/string_prctice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n=input("Enetr a string : ")
sum=0
for i in n:
  sum+=1
print(sum)
# Out:
# Enetr a string : ganduu
# 6

# %%
n=input("Enter a string : ")

post=n.index("@")
print(n[0:post])
# Out:
# Enter a string : vishnu@gmail.com
# vishnu

# %%
n=input("Enter a string : ")
x=input("What you want to search : ")
result=0
for i in n:
  if i==x:
    result+=1
print(result)
# Out:
# Enter a string : vishnui
# What you want to search : i
# 2

# %%
n=input("Enter a string : ")
x=input("What you want to search : ")
result=""
for i in n:
  if i!=x:
    result+=i
print(result)
# Out:
# Enter a string : vishnu
# What you want to search : i
# vshnu

# %%
s=input("Enter the string : ")
for i in n:
  print(i)
# Out:
# Enter the string : vishnu
# v
# i
# s
# h
# n
# u

# %%
s = input("Enter a palindrome: ")
flag = True

for i in range(0, len(s) // 2):
    if s[i] != s[len(s) - i - 1]:
        flag = False
        print("Not a palindrome")
        break

if flag:
    print("Palindrome")
# Out:
# Enter a palindrome: abba
# Palindrome
